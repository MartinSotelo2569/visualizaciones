# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinSotelo2569/visualizaciones/blob/main/PA1/Ejercicio_visualizacion_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_forbes = pd.read_excel('/content/drive/MyDrive/Bootcamp Data Analytics/Ejercicios de la plataforma Coding Dojo/Data Set_Forbes/forbes.xlsx')
df_forbes
# Out:
#     RANK                   NAME        SPORT  TOTAL EARNINGS   \
# 0      1      Cristiano Ronaldo       Soccer        136000000
# 1      2           Lionel Messi       Soccer        130000000
# 2      3          Kylian Mbappé       Soccer        120000000
# 3      4           LeBron James   Basketball        119500000
# 4      5         Canelo Alvarez       Boxing        110000000
# 5      6         Dustin Johnson         Golf        107000000
# 6      7         Phil Mickelson         Golf        106000000
# 7      8          Stephen Curry   Basketball        100400000
# 8      9          Roger Federer       Tennis         95100000
# 9     10           Kevin Durant   Basketball         89100000
# 10    11  Giannis Antetokounmpo   Basketball         87600000
# 11    12                 Neymar       Soccer         85000000
# 12    12         Russell Wilson     Football         85000000
# 13    14      Russell Westbrook   Basketball         82100000
# ...

# %%
df_forbes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RANK                     50 non-null     int64
#  1   NAME                     50 non-null     object
#  2   SPORT                    50 non-null     object
#  3   TOTAL EARNINGS           50 non-null     int64
#  4   ON-THE-FIELD EARNINGS    50 non-null     int64
#  5   OFF-THE-FIELD-EARNINGS   50 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 2.5+ KB

# %%
print(df_forbes.columns)
# Out:
# Index(['RANK', 'NAME', 'SPORT', 'TOTAL EARNINGS ', 'ON-THE-FIELD EARNINGS ',
#        'OFF-THE-FIELD-EARNINGS '],
#       dtype='object')

# %%
df_forbes.columns = df_forbes.columns.str.strip()
print(df_forbes.columns)
# Out:
# Index(['RANK', 'NAME', 'SPORT', 'TOTAL EARNINGS', 'ON-THE-FIELD EARNINGS',
#        'OFF-THE-FIELD-EARNINGS'],
#       dtype='object')

# %%
fig = px.bar(df_forbes, x='NAME', y='TOTAL EARNINGS', title='Ganancias Totales por Deportista')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df_forbes, names='SPORT', title='Distribución de Deportes entre Atletas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df_forbes, x='ON-THE-FIELD EARNINGS', y='OFF-THE-FIELD-EARNINGS',
                 color='SPORT', title='Ganancias en el Campo vs. Ganancias Fuera del Campo')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df_forbes, x='SPORT', y=['ON-THE-FIELD EARNINGS', 'OFF-THE-FIELD-EARNINGS'],
             barmode='group', title='Comparación de Ganancias en el Campo y Fuera del Campo por Deporte')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_soccer = df_forbes[df_forbes['SPORT'] == 'Soccer']
fig = px.bar(df_soccer, x='NAME', y='TOTAL EARNINGS', title='Ganancias Totales por Deportista - Fútbol')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df_soccer, x='ON-THE-FIELD EARNINGS', y='OFF-THE-FIELD-EARNINGS',
                 color='SPORT', title='Ganancias en el Campo vs. Ganancias Fuera del Campo - Fútbol')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df_soccer, x='NAME', y=['ON-THE-FIELD EARNINGS', 'OFF-THE-FIELD-EARNINGS'],
             title='Comparación de Ganancias en el Campo y Fuera del Campo por Deportista - Fútbol',
             barmode='stack')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_basketball = df_forbes[df_forbes['SPORT'] == 'Basketball']
fig = px.bar(df_basketball, x='NAME', y='TOTAL EARNINGS', title='Ganancias Totales por Deportista - Baloncesto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df_basketball, x='ON-THE-FIELD EARNINGS', y='OFF-THE-FIELD-EARNINGS',
                 color='SPORT', title='Ganancias en el Campo vs. Ganancias Fuera del Campo - Baloncesto')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df_basketball, x='NAME', y=['ON-THE-FIELD EARNINGS', 'OFF-THE-FIELD-EARNINGS'],
             title='Comparación de Ganancias en el Campo y Fuera del Campo por Deportista - Baloncesto',
             barmode='stack')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
